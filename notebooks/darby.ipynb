# %%
$:.unshift('../lib')
require 'darby'
require 'daru/view'
Daru::View.plotting_library = :googlecharts

# %%
@s = Darby::Stock.all.first

# %%
@s.stats_df.last(20)

# %%
@s.annualized_returns_for_timeframe(timeframe: '10y')

# %%
Daru::View::Plot.new(@s.plottable_df).show_in_iruby
# Out:
# "\n<div id='f974405c-b301-4781-b7ab-eb7745869ad1'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_f974405c_b301_4781_b7ab_eb7745869ad1});\n  function draw_f974405c_b301_4781_b7ab_eb7745869ad1() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"datetime\",\"label\":\"index\"});data_table.addColumn({\"type\":\"number\",\"label\":\"adjusted_close\"});data_table.addRow([{v: new Date(2001, 4, 31, 0, 0, 0)}, {v: 10000.0}]);data_table.addRow([{v: new Date(2001, 5, 1, 0, 0, 0)}, {v: 10069.684253290989}]);data_table.addRow([{v: new Date(2001, 5, 4, 0, 0, 0)}, {v: 10113.25858728987}]);data_table.addRow([{v: new Date(2001, 5, 5, 0, 0, 0)}, {v: 10261.32214289607}]);data_table.addRow([{v: new Date(2001, 5, 6, 0, 0, 0)}, {v: 10174.223019337194}]);data_table.addRow([{v: new Date(2001, 5, 7, 0, 0, 0)}, {v: 10226.492402360296}]);data_table.addRow([{v: new Date(2001, 5, 8, 0, 0, 0)}, {v: 10139.368506581977}]);data_table.addRow([{v: new Date(2001, 5, 11, 0, 0, 0)}, {v: 10034.854512755215}]);data_table.addRow([{v: new Date(2001, 5, 12, 0, 0, 0)}, {v: 10043.549561779437}]);data_table.addRow([{v: new Date(2001, 5, 13, 0, 0, 0)}, {v: 9947.730616976896}]);data_table.addRow([{v: new Date(2001, 5, 14, 0, 0, 0)}, {v: 9721.262986836044}]);data_table.addRow([{v: new Date(2001, 5, 15, 0, 0, 0)}, {v: 9695.12829532449}]);data_table.addRow([{v: new Date(2001, 5, 18, 0, 0, 0)}, {v: 9634.163863277166}]);data_table.addRow([{v: new Date(2001, 5, 19, 0, 0, 0)}, {v: 9660.273782569275}]);data_table.addRow([{v: new Date(2001, 5, 20, 0, 0, 0)}, {v: 9764.81254861548}]);data_table.addRow([{v: new Date(2001, 5, 21, 0, 0, 0)}, {v: 9843.216623150134}]);data_table.addRow([{v: new Date(2001, 5, 22, 0, 0, 0)}, {v: 9782.227418883367}]);data_table.addRow([{v: new Date(2001, 5, 25, 0, 0, 0)}, {v: 9719.528931475086}]);data_table.addRow([{v: new Date(2001, 5, 26, 0, 0, 0)}, {v: 9693.31992330521}]);data_table.addRow([{v: new Date(2001, 5, 27, 0, 0, 0)}, {v: 9693.31992330521}]);data_table.addRow([{v: new Date(2001, 5, 28, 0, 0, 0)}, {v: 9815.570826252608}]);data_table.addRow([{v: new Date(2001, 5, 29, 0, 0, 0)}, {v: 9867.96407037292}]);data_table.addRow([{v: new Date(2001, 6, 2, 0, 0, 0)}, {v: 9894.173078542799}]);data_table.addRow([{v: new Date(2001, 6, 3, 0, 0, 0)}, {v: 9885.42848507969}]);data_table.addRow([{v: new Date(2001, 6, 5, 0, 0, 0)}, {v: 9780.641996839066}]);data_table.addRow([{v: new Date(2001, 6, 6, 0, 0, 0)}, {v: 9518.675776237495}]);data_table.addRow([{v: new Date(2001, 6, 9, 0, 0, 0)}, {v: 9579.788841601474}]);data_table.addRow([{v: new Date(2001, 6, 10, 0, 0, 0)}, {v: 9457.537938654075}]);data_table.addRow([{v: new Date(2001, 6, 11, 0, 0, 0)}, {v: 9466.25775989774}]);data_table.addRow([{v: new Date(2001, 6, 12, 0, 0, 0)}, {v: 9693.31992330521}]);data_table.addRow([{v: new Date(2001, 6, 13, 0, 0, 0)}, {v: 9736.993346181858}]);data_table.addRow([{v: new Date(2001, 6, 16, 0, 0, 0)}, {v: 9623.462264478123}]);data_table.addRow([{v: new Date(2001, 6, 17, 0, 0, 0)}, {v: 9736.993346181858}]);data_table.addRow([{v: new Date(2001, 6, 18, 0, 0, 0)}, {v: 9632.182085721788}]);data_table.addRow([{v: new Date(2001, 6, 19, 0, 0, 0)}, {v: 9693.31992330521}]);data_table.addRow([{v: new Date(2001, 6, 20, 0, 0, 0)}, {v: 9693.31992330521}]);data_table.addRow([{v: new Date(2001, 6, 23, 0, 0, 0)}, {v: 9527.39559748116}]);data_table.addRow([{v: new Date(2001, 6, 24, 0, 0, 0)}, {v: 9387.680279826991}]);data_table.addRow([{v: new Date(2001, 6, 25, 0, 0, 0)}, {v: 9509.93118277439}]);data_table.addRow([{v: new Date(2001, 6, 26, 0, 0, 0)}, {v: 9632.182085721788}]);data_table.addRow([{v: new Date(2001, 6, 27, 0, 0, 0)}, {v: 9649.646500428558}]);data_table.addRow([{v: new Date(2001, 6, 30, 0, 0, 0)}, {v: 9640.926679184895}]);data_table.addRow([{v: new Date(2001, 6, 31, 0, 0, 0)}, {v: 9675.855508598437}]);data_table.addRow([{v: new Date(2001, 7, 1, 0, 0, 0)}, {v: 9719.528931475086}]);data_table.addRow([ ...
